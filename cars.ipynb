# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import log

# %%
cars_data = pd.read_csv("USA_cars_datasets.csv")
cars_data_year = cars_data.loc[cars_data["year"]> 2010,:]
cars_data = cars_data_year[["price", "year"]]
cars_data
# Out:
#       price  year
# 1      2899  2011
# 2      5350  2018
# 3     25000  2014
# 4     27700  2018
# 5      5700  2018
# ...     ...   ...
# 2494   7800  2019
# 2495   9200  2018
# 2496   9200  2018
# 2497   9200  2018
# 2498   9200  2018
#
# [2396 rows x 2 columns]

# %%
# N = 500
x = cars_data['year']
y = cars_data['price']
area = np.pi*3
# Plot
plt.scatter(x, y, s=area, marker="o", facecolors="red", edgecolors="black", alpha=0.5)
plt.title('Scatter plot pythonspot.com')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
y = np.log(y)
plt.scatter(x, y, s=area, marker="o", facecolors="red", edgecolors="black", alpha=0.5)
plt.title('Scatter plot pythonspot.com')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
y
# Out:
# 1        7.972121
# 2        8.584852
# 3       10.126631
# 4       10.229188
# 5        8.648221
#           ...
# 2494     8.961879
# 2495     9.126959
# 2496     9.126959
# 2497     9.126959
# 2498     9.126959
# Name: price, Length: 2396, dtype: float64

# %%
# year 2000 and greater
# intervse
